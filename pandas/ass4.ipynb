# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind

# %%
df= pd.read_csv('City_Zhvi_AllHomes.csv')

# %%
df.head()
# Out:
#    RegionID    RegionName State                           Metro    CountyName  \
# 0      6181      New York    NY                        New York        Queens
# 1     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim   Los Angeles
# 2     17426       Chicago    IL                         Chicago          Cook
# 3     13271  Philadelphia    PA                    Philadelphia  Philadelphia
# 4     40326       Phoenix    AZ                         Phoenix      Maricopa
#
#    SizeRank   1996-04   1996-05   1996-06   1996-07   ...     2015-11  \
# 0         1       NaN       NaN       NaN       NaN   ...      573600
# 1         2  155000.0  154600.0  154400.0  154200.0   ...      558200
# 2         3  109700.0  109400.0  109300.0  109300.0   ...      207800
# 3         4   50000.0   49900.0   49600.0   49400.0   ...      122300
# 4         5   87200.0   87700.0   88200.0   88400.0   ...      183800
#
# ...

# %%
df.columns.tolist()
# Out:
# ['RegionID',
#  'RegionName',
#  'State',
#  'Metro',
#  'CountyName',
#  'SizeRank',
#  '1996-04',
#  '1996-05',
#  '1996-06',
#  '1996-07',
#  '1996-08',
#  '1996-09',
#  '1996-10',
#  '1996-11',
#  '1996-12',
#  '1997-01',
#  '1997-02',
#  '1997-03',
#  '1997-04',
#  '1997-05',
#  '1997-06',
#  '1997-07',
#  '1997-08',
#  '1997-09',
#  '1997-10',
#  '1997-11',
#  '1997-12',
#  '1998-01',
#  '1998-02',
#  '1998-03',
#  '1998-04',
#  '1998-05',
#  '1998-06',
#  '1998-07',
#  '1998-08',
#  '1998-09',
#  '1998-10',
#  '1998-11',
#  '1998-12',
#  '1999-01',
#  '1999-02',
#  '1999-03',
#  '1999-04',
#  '1999-05',
#  '1999-06',
#  '1999-07',
#  '1999-08',
#  '1999-09',
#  '1999-10',
#  '1999-11',
#  '1999-12',
#  '2000-01',
#  '2000-02',
#  '2000-03',
#  '2000-04',
#  '2000-05',
#  '2000-06',
#  '2000-07',
#  '2000-08',
#  '2000-09',
#  '2000-10',
#  '2000-11',
#  '2000-12',
#  '2001-01',
#  '2001-02',
#  '2001-03',
#  '2001-04',
#  '2001-05',
#  '2001-06',
#  '2001-07',
#  '2001-08',
# ...

# %%
df2=pd.read_csv('university_towns.txt',sep='|',header=None,names=['RegionName'])

# %%
df2['State']=df2[df2['RegionName'].str.contains('edit')]
df2.head()
# Out:
#                                         RegionName          State
# 0                                    Alabama[edit]  Alabama[edit]
# 1                    Auburn (Auburn University)[1]            NaN
# 2           Florence (University of North Alabama)            NaN
# 3  Jacksonville (Jacksonville State University)[2]            NaN
# 4       Livingston (University of West Alabama)[2]            NaN

# %%
df2['State'].fillna(method='ffill',inplace=True)
# df['state'].head()

# %%
df2.head()
# Out:
#                                         RegionName          State
# 0                                    Alabama[edit]  Alabama[edit]
# 1                    Auburn (Auburn University)[1]  Alabama[edit]
# 2           Florence (University of North Alabama)  Alabama[edit]
# 3  Jacksonville (Jacksonville State University)[2]  Alabama[edit]
# 4       Livingston (University of West Alabama)[2]  Alabama[edit]

# %%
df2['check']=df2['State']== df2['RegionName']
# df2.loc[df2['check']== True].head()
df2.drop(df2.loc[df2['check']== True].index,inplace=True)

# %%
del df2['check']

# %%
df2['State'] = df2['State'].str.replace("\[.*?\]",'')
df2.head()
# Out:
#                                         RegionName    State
# 1                    Auburn (Auburn University)[1]  Alabama
# 2           Florence (University of North Alabama)  Alabama
# 3  Jacksonville (Jacksonville State University)[2]  Alabama
# 4       Livingston (University of West Alabama)[2]  Alabama
# 5         Montevallo (University of Montevallo)[2]  Alabama

# %%
df2['RegionName']=df2['RegionName'].str.replace(" \(.*?\)",'')
df2['RegionName']=df2['RegionName'].str.replace("\[.*?\]",'')
print(df2.shape)
df2.head()
# Out:
# (517, 2)
#      RegionName    State
# 1        Auburn  Alabama
# 2      Florence  Alabama
# 3  Jacksonville  Alabama
# 4    Livingston  Alabama
# 5    Montevallo  Alabama

# %%
df3=pd.read_excel('gdplev.xls',skiprows=6)

# %%
df3.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0         NaN         NaN         NaN         NaN        NaN         NaN
# 1      1929.0       104.6      1056.6         NaN     1947q1       243.1
# 2      1930.0        92.2       966.7         NaN     1947q2       246.3
# 3      1931.0        77.4       904.8         NaN     1947q3       250.1
# 4      1932.0        59.5       788.2         NaN     1947q4       260.3
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# 1      1934.5         NaN
# 2      1932.3         NaN
# 3      1930.3         NaN
# 4      1960.7         NaN

# %%
df3= df3.rename(columns={'Unnamed: 4':'Recession','Unnamed: 6':'Gdp'})

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 8 columns):
# Unnamed: 0    87 non-null float64
# Unnamed: 1    87 non-null float64
# Unnamed: 2    87 non-null float64
# Unnamed: 3    0 non-null float64
# Recession     278 non-null object
# Unnamed: 5    278 non-null float64
# Gdp           278 non-null float64
# Unnamed: 7    0 non-null float64
# dtypes: float64(7), object(1)
# memory usage: 17.5+ KB

# %%
GDP=df3[['Recession','Gdp']].copy()

# %%
GDP.dropna(inplace=True)

# %%
GDP.head()
# Out:
#   Recession     Gdp
# 1    1947q1  1934.5
# 2    1947q2  1932.3
# 3    1947q3  1930.3
# 4    1947q4  1960.7
# 5    1948q1  1989.5

# %%
# # GDP['Date'] = pd.to_datetime(GDP['Year'])
# GDP['Year'] = GDP['Year'].astype(int)

# GDP['Year'] = pd.to_datetime(GDP['Year'],format='%Y')

# %%
GDP[GDP['Recession'].str.contains('2008')]
# Out:
#     Recession      Gdp
# 245    2008q1  14889.5
# 246    2008q2  14963.4
# 247    2008q3  14891.6
# 248    2008q4  14577.0

# %%
 GDP.drop(GDP[0:212].index,inplace=True)

# %%
list_Gdp= GDP['Gdp'].tolist()
start_list=[]
for i in range(len(list_Gdp)-2):
    if(GDP.iloc[i+1][1] < GDP.iloc[i][1]) and (GDP.iloc[i+2][1] < GDP.iloc[i+1][1]):
        
        start_list.append(GDP.iloc[i])
        
print(start_list)
# Out:
# [Recession     2008q2
# Gdp          14963.4
# Name: 246, dtype: object, Recession     2008q3
# Gdp          14891.6
# Name: 247, dtype: object, Recession    2008q4
# Gdp           14577
# Name: 248, dtype: object]

# %%
list_Gdp= GDP['Gdp'].tolist()

end_list=[]
for i in range(len(list_Gdp)-2):
    if(GDP.iloc[i-1][1] < GDP.iloc[i][1]) & (GDP.iloc[i-2][1] < GDP.iloc[i-1][1]):
                    end_list.append(GDP.iloc[i])

        
        
print(end_list)
# Out:
# [Recession     2000q3
# Gdp          12607.7
# Name: 215, dtype: object, Recession     2000q4
# Gdp          12679.3
# Name: 216, dtype: object, Recession     2002q1
# Gdp          12822.3
# Name: 221, dtype: object, Recession    2002q2
# Gdp           12893
# Name: 222, dtype: object, Recession     2002q3
# Gdp          12955.8
# Name: 223, dtype: object, Recession    2002q4
# Gdp           12964
# Name: 224, dtype: object, Recession     2003q1
# Gdp          13031.2
# Name: 225, dtype: object, Recession     2003q2
# Gdp          13152.1
# Name: 226, dtype: object, Recession     2003q3
# Gdp          13372.4
# Name: 227, dtype: object, Recession     2003q4
# Gdp          13528.7
# Name: 228, dtype: object, Recession     2004q1
# Gdp          13606.5
# Name: 229, dtype: object, Recession     2004q2
# Gdp          13706.2
# Name: 230, dtype: object, Recession     2004q3
# Gdp          13830.8
# Name: 231, dtype: object, Recession     2004q4
# Gdp          13950.4
# ...

# %%
GDP['start'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'start'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
