# %%
# %matplotlib inline

import numpy as np 
from scipy import misc
import matplotlib.pyplot as plt

# %% [markdown]
# **create numpy from image ** use lab skimage importdata

# %%
from skimage import data

# %%
photo_data = misc.imread('./wifire/sd-3layers.jpg')
# Out:
# C:\Users\Doaa95\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
type(photo_data)
# Out:
# numpy.ndarray

# %%
#print(photo_data)

# %%
plt.figure(figsize=(10,15))
plt.imshow(photo_data)

# %%
photo_data.shape
# Out:
# (3725, 4797, 3)

# %%
photo_data2=misc.imread('./wifire/2_n.jpg')
#print(photo_data2)
# Out:
# C:\Users\Doaa95\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(12,12))
plt.imshow(photo_data2)

# %%
photo_data2.shape
# Out:
# (472, 960, 3)

# %%
print(photo_data.size)
print(photo_data2.size)
print(photo_data.mean())
print(photo_data2.mean())
print(photo_data.max())
print(photo_data.min())
print(photo_data2.max())
print(photo_data2.min())
# Out:
# 53606475
# 1359360
# 75.8299354508947
# 202.7421867643597
# 255
# 0
# 255
# 0

# %%
photo_data2[150,250]
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
photo_data2[100,100,1]
# Out:
# 255

# %%
photo_data2[250,150]=225
plt.figure(figsize=(15,15))
plt.imshow(photo_data2)

# %%
photo_data = misc.imread('./wifire/sd-3layers.jpg')

photo_data[200:800, : ,1] = 255
plt.figure(figsize=(10,10))
plt.imshow(photo_data)
# Out:
# C:\Users\Doaa95\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
photo_data2[300:400,:1]=(225,0,225)
plt.figure(figsize=(15,15))
plt.imshow(photo_data2)

# %%
filter_data2 = photo_data2 > 225
print(photo_data2.shape)
print(filter_data2.shape)
# Out:
# (472, 960, 3)
# (472, 960, 3)

# %%
filter_data = photo_data < 150
print(photo_data.shape)
print(filter_data.shape)
# Out:
# (3725, 4797, 3)
# (3725, 4797, 3)

# %%
photo_data2=misc.imread('./wifire/2_n.jpg')

photo_data2[filter_data2] =100
plt.figure(figsize=(15,15))
plt.imshow(photo_data2)
# Out:
# C:\Users\Doaa95\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
